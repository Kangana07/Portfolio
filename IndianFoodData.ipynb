# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\BAPS\Downloads\indian_food.csv")

# %%
data
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %%
data.shape
# Out:
# (255, 9)

# %%
data['region'] = data['region'].fillna('unknown')

# %%
data = data[~data.isin([-1]).any(axis=1)]

# %%
data
# Out:
#                   name                                        ingredients  \
# 0           Balu shahi                    Maida flour, yogurt, oil, sugar
# 1               Boondi                            Gram flour, ghee, sugar
# 2       Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3               Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4          Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..                 ...                                                ...
# 247  Prawn malai curry      Coconut milk, prawns, garlic, turmeric, sugar
# 249             Shukto  Green beans, bitter gourd, ridge gourd, banana...
# 250          Til Pitha            Glutinous rice, black sesame seeds, gur
# 251            Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 253          Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
#
#                diet  prep_time  cook_time flavor_profile       course  \
# ...

# %%
data.shape
# Out:
# (225, 9)

# %%
# Convert the specified columns to string to ensure '-1' is matched
columns_to_check = ['flavor_profile', 'state', 'region']
data[columns_to_check] = data[columns_to_check].astype(str)

# Drop rows where '-1' exists in the specified columns
data = data[~data[columns_to_check].isin(['-1']).any(axis=1)]

# Verify if '-1' is removed
print(data[columns_to_check].isin(['-1']).any())
# Out:
# flavor_profile    False
# state             False
# region            False
# dtype: bool
# C:\Users\BAPS\AppData\Local\Temp\ipykernel_572\1603322133.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[columns_to_check] = data[columns_to_check].astype(str)

# %%
data.to_csv(r"C:\Users\BAPS\Downloads\cleaned_indian_food.csv", index=False)
